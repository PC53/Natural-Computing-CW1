# %%
import numpy as np 
import random 
import matplotlib.pyplot as plt

# %%
def generate_sumplete_instance(k, deletion_rate=1/3,min_num=1,max_num=10):
    
    matrix = np.random.randint(min_num, max_num, (k, k))

    flat_matrix = matrix.flatten()
    num_deletions = int(len(flat_matrix) * deletion_rate)
    indexes_to_delete = random.sample(range(len(flat_matrix)), num_deletions)
    for index in indexes_to_delete:
        flat_matrix[index] = 0  

    # calculating the sums after delettion
    deleted_matrix = flat_matrix.reshape(k, k)
    target_row_sums = np.sum(deleted_matrix, axis=1)
    target_col_sums = np.sum(deleted_matrix, axis=0)
    
    # random values for deleted numbers
    for i in range(len(deleted_matrix)):
        for j in range(len(deleted_matrix[0])):
            if deleted_matrix[i][j] == 0:
                deleted_matrix[i][j] = np.random.randint(min_num,max_num)
    

    return deleted_matrix, target_row_sums, target_col_sums

######################################################
k = 6  
instance, row_sums, col_sums = generate_sumplete_instance(k)
print( instance)
print("target rows" ,row_sums)
print("target_cols", col_sums)
# Out:
# [[5 4 1 4 8 7]
#  [9 3 5 5 9 7]
#  [2 2 6 5 3 7]
#  [9 2 5 3 7 1]
#  [5 7 2 2 6 4]
#  [9 6 9 1 1 8]]
# target rows [21 28 19 26  7 18]
# target_cols [30 11 17 12 20 29]

# %%
########### FITNESS FUNCITONS #############
    
def fitness_part_b(self,chromosome): # Fitness is higher when the sum difference is lower
    current_row_sums = np.sum(chromosome * self.instance, axis=1)
    current_col_sums = np.sum(chromosome * self.instance, axis=0)
    row_diff = np.sum(np.abs(self.target_row_sums - current_row_sums))
    col_diff = np.sum(np.abs(self.target_col_sums - current_col_sums))
    return 1 / (1 + row_diff + col_diff)  

def fitness_part_a(self,chromosome): # 1 for correct and 0 for all others
    
    current_row_sums = np.sum(chromosome * self.instance, axis=1)
    current_col_sums = np.sum(chromosome * self.instance, axis=0)
    if np.array_equal(current_row_sums, self.target_row_sums) and np.array_equal(current_col_sums, self.target_col_sums):
        return 1
    else:
        return 0

# %%
########### SELECTION FUNCTIONS ##################

def tournament_selection(self, tournament_size):
       
        selected_parents = []
        for _ in range(len(self.population)):
            # Randomly select tournament participants
            participants = random.sample(self.population, tournament_size)
            # Evaluate the fitness of tournament participants
            participant_fitnesses = [self.calculate_fitness(individual) for individual in participants]
            # Select the best individual from participants
            winner_index = np.argmax(participant_fitnesses)
            selected_parents.append(participants[winner_index])
        
        return selected_parents

def practical_roulette_selection(population, fitness_scores):
    average_fitness = np.mean(fitness_scores)
    new_population = []
    
    for i, individual in enumerate(population):
        fitness = fitness_scores[i]
        
        if fitness == average_fitness:
            # The individual survives
            new_population.append(individual)
        elif fitness < average_fitness:
            # The individual survives with a probability of f_i / f̄
            if random.random() < (fitness / average_fitness):
                new_population.append(individual)
        else:
            # The individual produces floor(f_i / f̄) offspring
            offspring_count = int(fitness // average_fitness)
            new_population.extend([individual] * offspring_count)
            
            # The individual has a chance to produce one more offspring
            if random.random() < (fitness / average_fitness - offspring_count):
                new_population.append(individual)
    
    return new_population

# %%
####################### CROSSOVER METHODS #############################
def single_point_crossover(parent1, parent2, p_c):
    # Only perform crossover with probability p_c
    if np.random.rand() < p_c:
        # Choose a random crossover point
        crossover_point = np.random.randint(1, len(parent1))  # start from 1 to avoid null crossover
        # Create children by combining the parents at the crossover point
        child1 = np.vstack((parent1[:crossover_point, :], parent2[crossover_point:, :]))
        child2 = np.vstack((parent2[:crossover_point, :], parent1[crossover_point:, :]))
    else:
        # With probability 1 - p_c, copy the parents
        child1, child2 = np.copy(parent1), np.copy(parent2)

    return child1, child2

# %%
####################### MUTATION FUNCTIONS ####################
def mutate_bit_flip(chromosome, mutation_rate):
    mutation_matrix = np.random.rand(len(chromosome),len(chromosome)) < mutation_rate
    # XOR with mutation matrix will flip the bits where mutation_matrix is True
    chromosome = np.logical_xor(chromosome, mutation_matrix).astype(int)
    return chromosome

# previously used mutation function
# def mutate_random_resetting(chromosome, mutation_rate):
#     for i in range(len(chromosome)):
#         for j in range(self.k):
#             if np.random.rand() < mutation_rate:
#                 chromosome[i, j] = 1 if chromosome[i, j] == 0 else 0
#     return chromosome

# %%
########################### OPTIMALITY VERIFICATION ##################

def verify_solution(instance, solution, target_row_sums, target_col_sums):
    
    if solution is None:
        return(None,None,False)
    
    # Pretty Printing the instance
    max_num_width = 2
    separator = '-' * (instance.shape[1] * (max_num_width + 1) + 3)
    
    # Print the matrix with row sums
    for i, row in enumerate(instance):
        # Print the matrix row with proper formatting
        print(' '.join(f"{num:>{max_num_width}}" for num in row) + ' | ' + str(target_row_sums[i]))
 
    print(separator)
    # Print the column sums
    print(' '.join(f"{num:>{max_num_width}}" for num in target_col_sums) + ' |') 

    print('\n')
    
    
    # Calculate the sum of the rows and columns in the solution
    solution_row_sums = np.sum(solution * instance, axis=1)
    print("Solution Row Sums after deletion",solution_row_sums)
    solution_col_sums = np.sum(solution * instance, axis=0)
    print("Solution Column Sums after deletion",solution_col_sums)
    

    # Check if the calculated sums match the target sums
    is_row_correct = np.array_equal(solution_row_sums, target_row_sums)
    is_col_correct = np.array_equal(solution_col_sums, target_col_sums)

    # The solution is optimal if both row and column sums match the target sums
    print("is the solution optimal?? :",is_row_correct and is_col_correct)
    return (target_row_sums-solution_row_sums,target_col_sums-solution_col_sums,is_row_correct and is_col_correct)

# %%
################### GENETIC ALGORITHM SOLVER ###################

class GA:
    
    def __init__(self,population_size,instance,target_row_sums,target_col_sums,p_c,p_m, generations):
        self.k = len(instance)
        self.instance = instance
        self.target_row_sums = target_row_sums
        self.target_col_sums = target_col_sums
        self.population = self.generate_initial_population(population_size,self.k)
        self.generations = generations
        self.p_c = p_c
        self.p_m = p_m
        self.elitism_size = 10
        
        self.best_generation = None
    
    def generate_initial_population(self,population_size, k):
        population = []
        for _ in range(population_size):
            chromosome = np.random.choice([0, 1], (k, k))
            population.append(chromosome)
        return population
    
    def calculate_fitness(self,chromosome): # Fitness is higher when the sum difference is lower
        return fitness_part_b(self, chromosome)
    
    def select_parents(self,population, fitness_scores):
        return self.tournament_selection()

    def tournament_selection(self, tournament_size=3):
        
        selected_parents = []
        for _ in range(len(self.population)):
            # Randomly select tournament participants
            participants = random.sample(self.population, tournament_size)
            # Evaluate the fitness of tournament participants
            participant_fitnesses = [self.calculate_fitness(individual) for individual in participants]
            # Select the best individual from participants
            winner_index = np.argmax(participant_fitnesses)
            selected_parents.append(participants[winner_index])
        
        return selected_parents

    def crossover(self,parent1, parent2):
        return single_point_crossover(parent1, parent2, self.p_c)

    def mutate(self, chromosome): ### _bit_flip
        mutation_matrix = np.random.rand(self.k, self.k) < self.p_m
        
        chromosome = np.logical_xor(chromosome, mutation_matrix).astype(int)
        return chromosome
    
    def get_elite_group(self,fitness_values):
        sorted_population = [x for _,x in sorted(zip(fitness_values,self.population),key=lambda pair:pair[0], reverse=True)]
        
        return sorted_population[:self.elitism_size]


    def solve(self):
        best_solution = None
        best_fitness = 0

        for generation in range(self.generations):
            fitness_scores = [self.calculate_fitness(chromosome) for chromosome in self.population]
            
            # Check for the best solution
            current_best = max(fitness_scores)
            if current_best > best_fitness:
                best_fitness = current_best
                best_solution = self.population[np.argmax(fitness_scores)]

            if best_fitness == 1:  
                self.best_generation = generation
                break
            
            # Selection
            parents = self.select_parents(self.population, fitness_scores)
            # print("number of parents", len(parents))
            
            # Crossover and mutation
            # new_population = []
            new_population = self.get_elite_group(fitness_scores)
            
            for _ in range(len(parents) // 2):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1)
                child2 = self.mutate(child2)
                new_population.extend([child1, child2])
            
            self.population = new_population[:len(self.population)]
            
            
        self.best_generation = generation
        return best_solution

# DRIVER CODE 
k = 5 # Dimension of the matrix
population_size = 100
generations = 1000
mutation_rate = 0.01
crossover_rate = 0.7
instance, row_sums, col_sums = generate_sumplete_instance(k)
algorithm = GA(population_size,instance,row_sums,col_sums,crossover_rate,mutation_rate,generations)
solution = algorithm.solve()

# %% [markdown]
# ### Part A

# %%
population_size = 100
generations = 1000
mutation_rate = 0.01
crossover_rate = 0.7
number_of_convergence = {}
average_generations = {}
# Measuring the number of optimal solutions generated for different size problems
for k in range(3,7):
    number_of_convergence[k] = 0
    best_generations = []
    for _ in range(10):
        instance, row_sums, col_sums = generate_sumplete_instance(k)
        algorithm = GA(population_size,instance,row_sums,col_sums,crossover_rate,mutation_rate,generations)
        solution = algorithm.solve()
        if verify_solution(instance, solution, row_sums, col_sums)[2]:
            number_of_convergence[k] += 1
        best_generations.append(algorithm.best_generation)
    average_generations[k] = np.mean(best_generations)
# Out:
#  1  2  7 | 3
#  9  4  5 | 14
#  8  7  3 | 15
# ------------
# 18  9  5 |
#
#
# Solution Row Sums after deletion [ 3 14 15]
# Solution Column Sums after deletion [18  9  5]
# is the solution optimal?? : True
#  4  7  1 | 11
#  3  2  3 | 2
#  9  5  8 | 22
# ------------
# 13 14  8 |
#
#
# Solution Row Sums after deletion [11  2 22]
# Solution Column Sums after deletion [13 14  8]
# is the solution optimal?? : True
#  8  4  8 | 12
#  1  8  3 | 4
#  2  1  5 | 3
# ------------
# 11  5  3 |
#
#
# Solution Row Sums after deletion [12  4  3]
# Solution Column Sums after deletion [11  5  3]
# is the solution optimal?? : True
#  9  7  5 | 7
#  8  2  3 | 10
#  3  9  6 | 18
# ------------
# 11 18  6 |
#
#
# Solution Row Sums after deletion [ 7 10 18]
# Solution Column Sums after deletion [11 18  6]
# is the solution optimal?? : True
#  1  3  4 | 3
#  3  8  2 | 5
#  2  8  5 | 15
# ------------
#  5 11  7 |
#
#
# Solution Row Sums after deletion [ 3  5 15]
# Solution Column Sums after deletion [ 5 11  7]
# is the solution optimal?? : True
#  1  5  5 | 10
#  4  2  1 | 3
#  4  7  4 | 11
# ------------
#  4 14  6 |
#
#
# Solution Row Sums after deletion [10  3 11]
# Solution Column Sums after deletion [ 4 14  6]
# is the solution optimal?? : True
#  2  5  9 | 16
#  7  5  9 | 14
#  3  6  9 | 3
# ------------
#  5 10 18 |
#
#
# Solution Row Sums after deletion [16 14  3]
# Solution Column Sums after deletion [ 5 10 18]
# is the solution optimal?? : True
#  1  4  2 | 6
#  3  6  6 | 12
#  3  7  1 | 4
# ------------
#  3 10  9 |
#
#
# Solution Row Sums after deletion [ 6 12  4]
# Solution Column Sums after deletion [ 3 10  9]
# is the solution optimal?? : True
#  6  9  4 | 19
#  4  8  5 | 13
#  8  9  5 | 5
# ------------
#  6 17 14 |
#
#
# Solution Row Sums after deletion [19 13  5]
# Solution Column Sums after deletion [ 6 17 14]
# is the solution optimal?? : True
#  1  8  7 | 16
#  6  1  5 | 6
#  9  7  9 | 9
# ------------
#  1  9 21 |
#
#
# Solution Row Sums after deletion [16  6  9]
# Solution Column Sums after deletion [ 1  9 21]
# is the solution optimal?? : True
#  3  8  7  6 | 13
#  1  8  2  1 | 11
#  7  4  5  2 | 14
#  2  9  9  4 | 15
# ---------------
#  9 17 14 13 |
#
#
# Solution Row Sums after deletion [13 11 14 15]
# Solution Column Sums after deletion [ 9 17 14 13]
# is the solution optimal?? : True
#  2  8  7  1 | 17
#  5  9  2  1 | 11
#  6  2  2  1 | 7
#  5  7  2  1 | 15
# ---------------
# 13 24 11  2 |
#
#
# Solution Row Sums after deletion [17 11  7 15]
# Solution Column Sums after deletion [13 24 11  2]
# is the solution optimal?? : True
#  3  9  4  2 | 18
#  7  5  9  8 | 29
#  3  3  7  7 | 3
#  2  7  1  2 | 8
# ---------------
# 13 21 14 10 |
#
#
# Solution Row Sums after deletion [18 29  3  8]
# Solution Column Sums after deletion [13 21 14 10]
# is the solution optimal?? : True
#  6  1  1  5 | 12
#  5  7  4  7 | 16
#  9  4  8  4 | 12
#  4  2  6  3 | 13
# ---------------
# 15  1 18 19 |
#
#
# Solution Row Sums after deletion [12 16 12 13]
# Solution Column Sums after deletion [15  1 18 19]
# is the solution optimal?? : True
#  7  3  2  4 | 9
#  6  7  6  7 | 13
#  4  7  1  6 | 11
#  6  1  9  8 | 24
# ---------------
# 10 18 17 12 |
#
#
#  2  8  5  8 | 16
#  6  4  6  3 | 13
#  2  2  8  2 | 12
#  6  8  4  7 | 17
# ---------------
#  8 12 18 20 |
#
#
# Solution Row Sums after deletion [16 13 12 17]
# Solution Column Sums after deletion [ 8 12 18 20]
# is the solution optimal?? : True
#  5  3  4  8 | 20
#  3  6  1  6 | 10
#  9  7  8  6 | 16
#  6  5  9  4 | 15
# ---------------
# 23 10 14 14 |
#
#
#  2  7  7  6 | 2
#  6  9  1  3 | 18
#  6  1  9  4 | 20
#  4  9  1  9 | 22
# ---------------
# 18 19  9 16 |
#
#
# Solution Row Sums after deletion [ 2 18 20 22]
# Solution Column Sums after deletion [18 19  9 16]
# is the solution optimal?? : True
#  8  1  8  6 | 15
#  8  6  2  4 | 12
#  1  8  2  6 | 16
#  7  5  3  6 | 16
# ---------------
# 23  9  5 22 |
#
#
#  9  2  3  5 | 16
#  7  9  7  2 | 25
#  3  4  1  9 | 4
#  4  7  7  3 | 14
# ---------------
# 19 18 15  7 |
#
#
# Solution Row Sums after deletion [16 25  4 14]
# Solution Column Sums after deletion [19 18 15  7]
# is the solution optimal?? : True
#  2  5  2  3  9 | 18
#  9  1  7  6  5 | 21
#  6  8  9  8  5 | 22
#  3  9  1  6  9 | 22
#  1  9  4  5  6 | 9
# ------------------
# 20 23  7 19 23 |
#
#
#  7  7  6  1  9 | 8
#  9  7  1  5  2 | 14
#  9  7  5  5  8 | 34
#  1  4  7  4  6 | 17
#  3  4  1  7  3 | 15
# ------------------
# 16 22 13 18 19 |
#
#
#  1  9  5  4  3 | 12
#  9  7  4  1  6 | 12
#  6  1  9  6  1 | 17
#  7  2  8  4  3 | 16
#  2  9  8  1  3 | 13
# ------------------
#  7 19 18 16 10 |
#
#
#  5  6  1  5  5 | 17
#  6  8  2  2  4 | 6
#  7  7  9  5  7 | 28
#  9  3  4  4  5 | 17
#  9  1  9  3  2 | 24
# ------------------
# 36  7 23 17  9 |
#
#
#  6  6  7  5  2 | 20
#  2  8  9  9  1 | 12
#  5  5  4  3  3 | 15
#  6  8  8  3  4 | 23
#  5  3  3  3  5 | 8
# ------------------
# 13 13 28 14 10 |
#
#
#  8  4  4  8  2 | 8
#  1  3  2  5  2 | 13
#  8  9  4  2  7 | 17
#  9  7  8  7  7 | 24
#  5  2  1  5  1 | 12
# ------------------
# 23  7 15 19 10 |
#
#
#  5  3  4  3  9 | 12
#  1  2  7  9  1 | 10
#  6  6  1  7  8 | 22
#  2  3  4  5  5 | 9
#  5  7  6  8  3 | 21
# ------------------
# 19 12 22 10 11 |
#
#
#  4  8  4  8  7 | 11
#  7  1  9  4  4 | 17
#  4  2  6  3  1 | 16
#  4  7  3  2  3 | 12
#  7  4  5  7  5 | 17
# ------------------
# 26  3 23  5 16 |
#
#
#  5  7  5  3  3 | 7
#  9  5  6  9  9 | 33
#  6  8  9  5  1 | 16
#  2  8  6  4  1 | 13
#  9  2  3  8  7 | 29
# ------------------
# 26  9 24 21 18 |
#
#
#  6  8  7  8  9 | 30
#  9  8  7  7  7 | 22
#  3  2  2  3  3 | 10
#  9  2  2  9  8 | 4
#  5  4  3  5  3 | 16
# ------------------
# 14 12 21 20 15 |
#
#
#  7  2  1  9  7  8 | 9
#  9  9  1  2  1  7 | 20
#  5  5  8  7  1  7 | 16
#  6  3  1  3  7  6 | 26
#  6  5  1  4  4  4 | 23
#  3  2  1  3  2  9 | 10
# ---------------------
# 24 19 11 17 15 18 |
#
#
#  4  7  1  8  1  2 | 9
#  4  4  5  2  5  3 | 19
#  3  9  2  7  3  7 | 24
#  7  5  1  2  3  5 | 23
#  2  6  4  3  1  9 | 16
#  9  6  2  8  6  7 | 21
# ---------------------
# 19 24 13 15 17 24 |
#
#
#  6  7  8  6  4  5 | 13
#  6  5  4  5  7  9 | 30
#  4  1  5  4  3  8 | 18
#  9  2  2  7  3  4 | 14
#  6  2  5  4  4  1 | 15
#  7  7  9  8  4  7 | 42
# ---------------------
# 17 15 33 24 14 29 |
#
#
#  4  7  5  9  3  6 | 14
#  9  7  4  3  3  9 | 25
#  5  2  4  8  3  8 | 14
#  3  9  8  8  3  5 | 31
#  5  1  3  5  3  9 | 14
#  1  2  5  4  3  5 | 14
# ---------------------
# 26 21 24 20 12  9 |
#
#
#  2  1  9  6  6  8 | 31
#  3  8  5  8  4  6 | 34
#  6  8  5  5  2  1 | 17
#  9  5  7  7  1  5 | 29
#  4  6  3  9  3  2 | 15
#  2  9  5  5  4  4 | 13
# ---------------------
# 20 36 21 30 17 15 |
#
#
#  4  9  6  5  5  6 | 20
#  5  5  2  9  6  4 | 11
#  2  5  6  2  4  7 | 20
#  7  8  4  7  7  3 | 29
#  1  3  9  4  4  4 | 18
#  2  5  3  1  3  6 | 14
# ---------------------
# 12 27 24 21 14 14 |
#
#
#  5  6  3  1  8  1 | 21
#  8  1  2  6  1  5 | 20
#  4  1  9  2  3  9 | 5
#  8  4  6  6  9  2 | 22
#  9  4  7  3  1  6 | 26
#  5  9  3  6  4  2 | 23
# ---------------------
# 39 17 16 22  9 14 |
#
#
#  6  6  5  8  5  3 | 27
#  4  5  3  1  9  2 | 10
#  4  5  5  4  5  5 | 10
#  9  9  8  9  6  1 | 32
#  2  8  5  4  4  1 | 16
#  6  8  4  9  8  8 | 35
# ---------------------
# 12 33 27 31 23  4 |
#
#
#  7  8  8  6  6  2 | 29
#  7  9  8  9  3  4 | 30
#  5  4  1  7  3  9 | 17
#  8  6  5  8  6  4 | 31
#  8  1  4  6  6  1 | 19
#  4  2  1  1  4  6 | 13
# ---------------------
# 27 26 27 36  0 23 |
#
#
#  6  6  8  6  4  2 | 24
#  3  2  3  6  6  9 | 20
#  7  2  4  4  4  8 | 25
#  9  1  6  8  5  1 | 24
#  6  8  6  2  2  4 | 22
#  8  2  8  4  3  1 | 10
# ---------------------
# 39 21 27 16 14  8 |

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(12,8))

ax1.bar(number_of_convergence.keys(),number_of_convergence.values(),label = 'Solve Count',color='grey')
ax1.set_xlabel("Dimension of Problem instance")
ax1.set_xticks([int(x) for x in number_of_convergence.keys()])
ax1.set_ylabel("Number of times solved (out of 10)")
ax1.legend()
ax1.set_title("Performance of GA algorithm with All-or-Out fitness (part a)")

ax2 = ax1.twinx()
ax2.plot(average_generations.keys(),average_generations.values(), label='Average Generations required',color='r',marker='.')
ax2.set_ylabel("Average Generations taken by algorithm")
ax2.legend()

fig.savefig('part_a.png')

# %% [markdown]
# ### Part B

# %%
population_size = 100
generations = 1000
mutation_rate = 0.1
crossover_rate = 0.8
# number_of_convergence_b = {}
# average_generations_b = {}
# Measuring the number of optimal solutions generated for different size problems
for k in range(6,7):
    number_of_convergence_b[k] = 0
    best_generations = []
    for _ in range(10):
        instance, row_sums, col_sums = generate_sumplete_instance(k)
        algorithm = GA(population_size,instance,row_sums,col_sums,crossover_rate,mutation_rate,generations)
        solution = algorithm.solve()
        if verify_solution(instance, solution, row_sums, col_sums)[2]:
            number_of_convergence_b[k] += 1
        best_generations.append(algorithm.best_generation)
    average_generations_b[k] = np.mean(best_generations)
# Out:
#  2  1  4  5  8  6 | 23
#  1  3  3  4  6  5 | 16
#  4  8  8  4  7  1 | 13
#  2  4  7  5  8  2 | 24
#  5  2  8  2  7  9 | 31
#  7  2  2  8  3  1 | 11
# ---------------------
# 10  9 32 22 23 22 |
#
#
# Solution Row Sums after deletion [23 16 13 24 31 12]
# Solution Column Sums after deletion [13  9 32 20 23 22]
# is the solution optimal?? : False
#  9  7  2  7  3  2 | 19
#  6  2  8  8  1  6 | 17
#  5  6  5  2  3  4 | 10
#  9  7  3  4  1  6 | 24
#  9  4  3  9  1  8 | 34
#  7  6  8  8  1  9 | 18
# ---------------------
# 32 13 22 22 10 23 |
#
#
# Solution Row Sums after deletion [19 17 10 23 34 17]
# Solution Column Sums after deletion [31 13 21 22 10 23]
# is the solution optimal?? : False
#  6  8  1  9  9  4 | 28
#  9  6  3  6  9  1 | 33
#  1  1  9  6  7  3 | 12
#  2  3  3  1  6  9 | 13
#  7  5  3  8  2  7 | 15
#  5  9  1  3  4  7 | 22
# ---------------------
# 21 27  8 15 31 21 |
#
#
# Solution Row Sums after deletion [28 33 13 13 12 24]
# Solution Column Sums after deletion [22 26  8 16 31 20]
# is the solution optimal?? : False
#  3  9  9  6  7  9 | 34
#  6  3  3  4  4  6 | 20
#  1  1  9  3  1  3 | 14
#  3  3  6  1  1  6 | 15
#  4  6  2  3  4  2 | 17
#  3  5  1  7  9  5 | 19
# ---------------------
# 14 19 27 23 24 12 |
#
#
# Solution Row Sums after deletion [34 20 14 15 17 17]
# Solution Column Sums after deletion [14 19 25 23 24 12]
# is the solution optimal?? : False
#  5  1  3  4  6  1 | 20
#  1  5  8  7  4  7 | 31
#  9  8  5  9  1  9 | 32
#  7  5  8  3  5  1 | 5
#  5  3  7  2  6  4 | 22
#  9  8  5  1  6  6 | 20
# ---------------------
# 28 19 28 11 23 21 |
#
#
# Solution Row Sums after deletion [20 31 32  5 22 20]
# Solution Column Sums after deletion [28 19 28 11 23 21]
# is the solution optimal?? : True
#  4  9  3  9  8  6 | 22
#  9  4  3  2  4  2 | 16
#  5  8  2  5  9  5 | 24
#  9  7  4  7  6  3 | 26
#  3  5  8  8  3  6 | 14
#  1  1  4  8  3  9 | 17
# ---------------------
# 26 21 16 24 18 14 |
#
#
# Solution Row Sums after deletion [21 15 24 26 14 17]
# Solution Column Sums after deletion [26 20 15 24 18 14]
# is the solution optimal?? : False
#  5  8  5  7  3  7 | 27
#  2  2  3  7  6  6 | 13
#  2  1  8  1  5  8 | 25
#  9  8  3  6  1  3 | 21
#  7  6  7  6  4  8 | 26
#  5  5  9  9  8  8 | 27
# ---------------------
# 23 22 23 24 18 29 |
#
#
# Solution Row Sums after deletion [27 13 25 21 25 26]
# Solution Column Sums after deletion [23 23 20 24 18 29]
# is the solution optimal?? : False
#  7  2  6  6  5  3 | 26
#  7  2  9  5  5  4 | 25
#  1  5  1  9  2  1 | 11
#  6  2  6  8  5  8 | 22
#  5  7  1  1  7  6 | 8
#  4  9  2  1  2  9 | 18
# ---------------------
# 25  4 24 22  7 28 |
#
#
# Solution Row Sums after deletion [26 25 11 22  8 18]
# Solution Column Sums after deletion [25  4 24 22  7 28]
# is the solution optimal?? : True
#  1  4  1  7  7  5 | 11
#  9  2  8  3  6  1 | 14
#  4  3  8  1  5  3 | 13
#  9  7  5  1  5  1 | 23
#  4  5  3  5  1  5 | 18
#  2  8  4  4  8  5 | 21
# ---------------------
# 17 21 20 21  6 15 |
#
#
# Solution Row Sums after deletion [12 14 13 22 18 21]
# Solution Column Sums after deletion [18 22 20 20  5 15]
# is the solution optimal?? : False
#  9  4  1  1  9  1 | 15
#  3  7  2  4  8  8 | 19
#  7  5  3  6  6  7 | 17
#  5  4  4  3  6  7 | 19
#  9  5  6  9  6  2 | 35
#  5  3  5  1  8  8 | 22
# ---------------------
# 19 28 16 21 27 16 |
#
#
# Solution Row Sums after deletion [15 19 18 19 35 22]
# Solution Column Sums after deletion [19 28 16 21 29 15]
# is the solution optimal?? : False

# %%
fig2, (ax21) = plt.subplots(1,1,figsize=(12,8))

ax21.bar(number_of_convergence_b.keys(),number_of_convergence_b.values(),label = 'Solve Count',color='grey')
ax21.set_xlabel("Dimension of Problem instance")
ax21.set_xticks([int(x) for x in number_of_convergence_b.keys()])
ax21.set_ylabel("Number of times solved (out of 10)")
ax21.legend()
ax21.set_title("Performance of GA algorithm with smooth fitness (part b)")

ax22 = ax21.twinx()
ax22.plot(average_generations_b.keys(),average_generations_b.values(), label='Average Generations required',color='r',marker='.')
ax22.set_ylabel("Average Generations taken by algorithm")
ax22.legend()

fig2.savefig('part_2b.png')

# %%
number_of_convergence_b
# Out:
# {3: 10, 4: 10, 5: 5, 6: 3}

# %% [markdown]
# ### Part C

# %%
k = 4
population_size = 100
generations = 1000
crossover_rate = 0.8
number_of_convergence_m = {}
average_generations_m = {}
# Measuring the number of optimal solutions generated for different parameters
for m in [0.01,0.05,0.1,0.2]:
    number_of_convergence_m[str(m)] = 0
    best_generations = []
    for _ in range(10):
        instance, row_sums, col_sums = generate_sumplete_instance(k)
        algorithm = GA(population_size,instance,row_sums,col_sums,crossover_rate,m,generations)
        solution = algorithm.solve()
        if verify_solution(instance, solution, row_sums, col_sums)[2]:
            number_of_convergence_m[str(m)] += 1
        best_generations.append(algorithm.best_generation)
    average_generations_m[str(m)] = np.mean(best_generations)
# Out:
#  2  4  4  4 | 8
#  1  9  2  8 | 12
#  5  7  2  9 | 14
#  8  8  1  9 | 18
# ---------------
#  6 24  9 13 |
#
#
# Solution Row Sums after deletion [ 8 12 14 18]
# Solution Column Sums after deletion [ 6 24  9 13]
# is the solution optimal?? : True
#  9  9  3  4 | 13
#  1  1  7  8 | 16
#  1  3  1  6 | 4
#  9  5  1  1 | 16
# ---------------
# 19  9  8 13 |
#
#
# Solution Row Sums after deletion [13 16  4 16]
# Solution Column Sums after deletion [19  9  8 13]
# is the solution optimal?? : True
#  5  1  2  5 | 13
#  8  7  9  1 | 1
#  8  4  8  1 | 9
#  1  4  6  5 | 16
# ---------------
#  6  5 16 12 |
#
#
# Solution Row Sums after deletion [13  1  9 16]
# Solution Column Sums after deletion [ 6  5 16 12]
# is the solution optimal?? : True
#  1  7  9  1 | 9
#  5  9  3  6 | 17
#  8  2  8  2 | 12
#  8  3  1  6 | 9
# ---------------
#  6 21 11  9 |
#
#
# Solution Row Sums after deletion [ 8 18 12 11]
# Solution Column Sums after deletion [ 8 21 11  9]
# is the solution optimal?? : False
#  1  8  7  1 | 1
#  9  6  6  3 | 24
#  9  1  2  4 | 7
#  7  8  6  5 | 19
# ---------------
#  9 15 14 13 |
#
#
# Solution Row Sums after deletion [ 1 24  7 19]
# Solution Column Sums after deletion [ 9 15 14 13]
# is the solution optimal?? : True
#  1  6  3  8 | 9
#  7  4  6  2 | 19
#  2  8  3  5 | 10
#  3  6  4  3 | 13
# ---------------
# 13 18 10 10 |
#
#
# Solution Row Sums after deletion [ 9 19 10 13]
# Solution Column Sums after deletion [13 18 10 10]
# is the solution optimal?? : True
#  1  1  8  4 | 9
#  2  3  7  2 | 12
#  6  5  3  6 | 15
#  5  1  6  6 | 13
# ---------------
#  8  5 24 12 |
#
#
# Solution Row Sums after deletion [ 9 12 15 13]
# Solution Column Sums after deletion [ 8  5 24 12]
# is the solution optimal?? : True
#  6  8  4  6 | 16
#  1  8  5  6 | 20
#  2  4  9  9 | 11
#  1  7  6  3 | 10
# ---------------
#  9 15 18 15 |
#
#
# Solution Row Sums after deletion [16 20 11 10]
# Solution Column Sums after deletion [ 9 15 18 15]
# is the solution optimal?? : True
#  9  9  6  9 | 24
#  6  9  6  8 | 29
#  1  7  4  6 | 7
#  6  4  8  9 | 10
# ---------------
# 22 13 12 23 |
#
#
# Solution Row Sums after deletion [24 29  7 10]
# Solution Column Sums after deletion [22 13 12 23]
# is the solution optimal?? : True
#  8  9  8  7 | 24
#  5  8  1  5 | 19
#  1  8  7  6 | 7
#  1  8  1  5 | 6
# ---------------
# 14 17  2 23 |
#
#
# Solution Row Sums after deletion [24 19  7  6]
# Solution Column Sums after deletion [14 17  2 23]
# is the solution optimal?? : True
#  6  9  9  8 | 23
#  9  2  7  8 | 18
#  2  5  4  6 | 15
#  3  8  8  7 | 15
# ---------------
# 15 24 11 21 |
#
#
# Solution Row Sums after deletion [23 18 15 15]
# Solution Column Sums after deletion [15 24 11 21]
# is the solution optimal?? : True
#  3  7  9  8 | 9
#  6  4  2  3 | 13
#  8  2  3  4 | 13
#  7  3  1  6 | 17
# ---------------
# 21  9 13  9 |
#
#
# Solution Row Sums after deletion [ 9 13 13 17]
# Solution Column Sums after deletion [21  9 13  9]
# is the solution optimal?? : True
#  9  3  2  1 | 15
#  4  9  5  6 | 20
#  6  6  4  9 | 15
#  7  5  6  6 | 11
# ---------------
#  9 23 13 16 |
#
#
# Solution Row Sums after deletion [15 20 15 11]
# Solution Column Sums after deletion [ 9 23 13 16]
# is the solution optimal?? : True
#  3  7  7  7 | 17
#  1  8  7  7 | 15
#  8  7  3  9 | 10
#  1  2  9  1 | 12
# ---------------
#  5  9 26 14 |
#
#
# Solution Row Sums after deletion [17 15 10 12]
# Solution Column Sums after deletion [ 5  9 26 14]
# is the solution optimal?? : True
#  8  7  7  9 | 31
#  3  6  7  1 | 13
#  9  1  1  5 | 7
#  9  3  3  6 | 9
# ---------------
#  8 14 18 20 |
#
#
# Solution Row Sums after deletion [31 13  7  9]
# Solution Column Sums after deletion [ 8 14 18 20]
# is the solution optimal?? : True
#  4  5  3  6 | 6
#  6  2  5  5 | 18
#  8  2  5  2 | 15
#  6  4  4  9 | 19
# ---------------
# 20  2 14 22 |
#
#
# Solution Row Sums after deletion [ 6 18 15 19]
# Solution Column Sums after deletion [20  2 14 22]
# is the solution optimal?? : True
#  9  9  1  3 | 13
#  8  6  4  7 | 18
#  5  6  5  6 | 12
#  5  5  9  7 | 19
# ---------------
# 22 17 14  9 |
#
#
# Solution Row Sums after deletion [13 18 12 19]
# Solution Column Sums after deletion [22 17 14  9]
# is the solution optimal?? : True
#  5  1  4  8 | 18
#  6  7  6  7 | 13
#  3  8  5  5 | 13
#  7  7  9  6 | 13
# ---------------
# 15  8 15 19 |
#
#
# Solution Row Sums after deletion [18 13 13 13]
# Solution Column Sums after deletion [15  8 15 19]
# is the solution optimal?? : True
#  3  6  3  1 | 6
#  3  5  9  1 | 15
#  5  5  5  5 | 10
#  7  5  9  3 | 24
# ---------------
# 10 15 21  9 |
#
#
# Solution Row Sums after deletion [ 6 15 10 24]
# Solution Column Sums after deletion [10 15 21  9]
# is the solution optimal?? : True
#  1  4  9  2 | 12
#  9  6  1  6 | 10
#  1  6  9  1 | 17
#  3  6  1  6 | 7
# ---------------
# 11  6 20  9 |
#
#
# Solution Row Sums after deletion [12 10 17  7]
# Solution Column Sums after deletion [11  6 20  9]
# is the solution optimal?? : True
#  6  1  8  3 | 9
#  3  2  3  9 | 15
#  5  1  6  3 | 9
#  6  7  4  1 | 14
# ---------------
# 14  9 11 13 |
#
#
# Solution Row Sums after deletion [ 9 15  9 14]
# Solution Column Sums after deletion [14  9 11 13]
# is the solution optimal?? : True
#  8  7  3  8 | 19
#  2  5  6  6 | 19
#  2  3  6  1 | 4
#  2  3  3  3 | 5
# ---------------
# 12  8  9 18 |
#
#
# Solution Row Sums after deletion [19 19  4  5]
# Solution Column Sums after deletion [12  8  9 18]
# is the solution optimal?? : True
#  6  9  8  7 | 22
#  8  6  4  1 | 1
#  4  3  5  9 | 21
#  8  9  8  8 | 25
# ---------------
# 18 21 13 17 |
#
#
# Solution Row Sums after deletion [22  1 21 25]
# Solution Column Sums after deletion [18 21 13 17]
# is the solution optimal?? : True
#  5  6  2  8 | 10
#  9  3  6  9 | 24
#  9  4  2  6 | 21
#  7  7  1  3 | 14
# ---------------
# 25 11 10 23 |
#
#
# Solution Row Sums after deletion [10 24 21 14]
# Solution Column Sums after deletion [25 11 10 23]
# is the solution optimal?? : True
#  9  2  3  7 | 10
#  7  2  4  6 | 19
#  9  4  4  8 | 17
#  9  2  9  6 | 17
# ---------------
# 25  4  7 27 |
#
#
# Solution Row Sums after deletion [10 19 17 17]
# Solution Column Sums after deletion [25  4  7 27]
# is the solution optimal?? : True
#  8  2  8  1 | 18
#  2  4  7  7 | 14
#  8  7  8  5 | 21
#  9  6  2  8 | 17
# ---------------
# 25  8 25 12 |
#
#
# Solution Row Sums after deletion [18 14 21 17]
# Solution Column Sums after deletion [25  8 25 12]
# is the solution optimal?? : True
#  8  3  2  8 | 13
#  5  8  1  6 | 15
#  3  7  1  7 | 17
#  3  1  7  5 | 10
# ---------------
# 14 18 10 13 |
#
#
# Solution Row Sums after deletion [13 15 17 10]
# Solution Column Sums after deletion [14 18 10 13]
# is the solution optimal?? : True
#  9  5  7  6 | 27
#  7  6  7  9 | 7
#  5  6  8  7 | 19
#  3  6  2  2 | 11
# ---------------
# 17 17 24  6 |
#
#
# Solution Row Sums after deletion [27  7 19 11]
# Solution Column Sums after deletion [17 17 24  6]
# is the solution optimal?? : True
#  6  4  7  3 | 14
#  2  5  2  1 | 6
#  1  6  4  5 | 15
#  2  7  2  4 | 13
# ---------------
#  0 22 13 13 |
#
#
# Solution Row Sums after deletion [14  6 15 13]
# Solution Column Sums after deletion [ 0 22 13 13]
# is the solution optimal?? : True
#  6  5  6  6 | 17
#  2  4  3  2 | 5
#  5  5  7  4 | 17
#  7  1  6  4 | 11
# ---------------
# 13 11 16 10 |
#
#
# Solution Row Sums after deletion [17  5 17 11]
# Solution Column Sums after deletion [13 11 16 10]
# is the solution optimal?? : True
#  1  1  1  5 | 7
#  1  4  7  8 | 16
#  3  9  2  7 | 11
#  2  6  6  3 | 15
# ---------------
#  1 16 16 16 |
#
#
# Solution Row Sums after deletion [ 7 16 11 15]
# Solution Column Sums after deletion [ 1 16 16 16]
# is the solution optimal?? : True
#  5  1  1  6 | 12
#  1  5  7  4 | 5
#  1  6  9  7 | 10
#  3  3  2  6 | 14
# ---------------
# 10  3 12 16 |
#
#
# Solution Row Sums after deletion [12  5 10 14]
# Solution Column Sums after deletion [10  3 12 16]
# is the solution optimal?? : True
#  3  5  1  7 | 16
#  9  5  9  2 | 7
#  9  2  4  3 | 6
#  9  2  5  6 | 20
# ---------------
# 12 12 10 15 |
#
#
# Solution Row Sums after deletion [16  7  6 20]
# Solution Column Sums after deletion [12 12 10 15]
# is the solution optimal?? : True
#  4  4  5  3 | 8
#  5  6  7  6 | 18
#  7  3  6  2 | 8
#  4  4  6  7 | 21
# ---------------
#  9 10 24 12 |
#
#
# Solution Row Sums after deletion [ 8 18  8 21]
# Solution Column Sums after deletion [ 9 10 24 12]
# is the solution optimal?? : True
#  6  8  4  7 | 17
#  5  3  1  5 | 6
#  6  9  1  3 | 13
#  6  2  2  2 | 10
# ---------------
# 17  9  8 12 |
#
#
# Solution Row Sums after deletion [17  6 13 10]
# Solution Column Sums after deletion [17  9  8 12]
# is the solution optimal?? : True
#  3  6  2  4 | 9
#  2  6  5  3 | 11
#  2  7  1  6 | 8
#  1  6  5  9 | 16
# ---------------
#  6 19  3 16 |
#
#
# Solution Row Sums after deletion [ 9 11  8 16]
# Solution Column Sums after deletion [ 6 19  3 16]
# is the solution optimal?? : True
#  8  6  8  8 | 22
#  5  3  4  7 | 9
#  2  3  9  4 | 9
#  9  9  2  5 | 20
# ---------------
# 16 18 14 12 |
#
#
# Solution Row Sums after deletion [22  9  9 20]
# Solution Column Sums after deletion [16 18 14 12]
# is the solution optimal?? : True
#  9  6  7  3 | 25
#  7  2  6  1 | 2
#  6  7  8  3 | 24
#  2  8  4  6 | 10
# ---------------
# 17 23 15  6 |
#
#
# Solution Row Sums after deletion [25  2 24 10]
# Solution Column Sums after deletion [17 23 15  6]
# is the solution optimal?? : True
#  9  9  6  2 | 8
#  3  1  9  2 | 15
#  2  2  1  5 | 6
#  1  4  6  9 | 19
# ---------------
#  3  5 22 18 |
#
#
# Solution Row Sums after deletion [ 8 15  6 19]
# Solution Column Sums after deletion [ 3  5 22 18]
# is the solution optimal?? : True
#  6  7  4  4 | 17
#  8  4  6  2 | 20
#  8  6  4  1 | 11
#  6  9  4  9 | 9
# ---------------
# 14 17 14 12 |
#
#
# Solution Row Sums after deletion [17 20 11  9]
# Solution Column Sums after deletion [14 17 14 12]
# is the solution optimal?? : True

# %%
number_of_convergence_m
# Out:
# {'0.01': 9, '0.05': 10, '0.1': 10, '0.2': 10}

# %%
k = 4
population_size = 100
generations = 1000
mutation_rate = 0.01
number_of_convergence_c = {}
average_generations_c = {}
# Measuring the number of optimal solutions generated for different parameters
for c in [0.5,0.6,0.7,0.8,0.9]:
    number_of_convergence_c[c] = 0
    best_generations = []
    for _ in range(10):
        instance, row_sums, col_sums = generate_sumplete_instance(k)
        algorithm = GA(population_size,instance,row_sums,col_sums,c,mutation_rate,generations)
        solution = algorithm.solve()
        if verify_solution(instance, solution, row_sums, col_sums)[2]:
            number_of_convergence_c[c] += 1
        best_generations.append(algorithm.best_generation)
    average_generations_c[c] = np.mean(best_generations)
# Out:
#  4  7  7  5 | 23
#  6  9  6  3 | 6
#  6  5  4  5 | 14
#  3  5  1  5 | 9
# ---------------
# 13 12 12 15 |
#
#
# Solution Row Sums after deletion [23  6 14  9]
# Solution Column Sums after deletion [13 12 12 15]
# is the solution optimal?? : True
#  3  4  7  9 | 19
#  7  5  4  6 | 22
#  8  3  3  7 | 11
#  8  6  4  3 | 10
# ---------------
# 18 11 18 15 |
#
#
# Solution Row Sums after deletion [19 22 11 10]
# Solution Column Sums after deletion [18 11 18 15]
# is the solution optimal?? : True
#  8  3  7  1 | 7
#  7  6  6  6 | 19
#  9  7  5  1 | 21
#  8  3  9  7 | 27
# ---------------
# 24 16 27  7 |
#
#
# Solution Row Sums after deletion [ 7 19 21 27]
# Solution Column Sums after deletion [24 16 27  7]
# is the solution optimal?? : True
#  1  7  8  7 | 9
#  9  4  9  2 | 24
#  2  4  5  3 | 14
#  4  2  3  5 | 5
# ---------------
# 12  8 22 10 |
#
#
# Solution Row Sums after deletion [ 9 24 14  5]
# Solution Column Sums after deletion [12  8 22 10]
# is the solution optimal?? : True
#  6  7  1  9 | 16
#  6  4  3  9 | 16
#  6  5  6  8 | 11
#  7  8  7  6 | 22
# ---------------
# 19 17 11 18 |
#
#
# Solution Row Sums after deletion [16 15 12 22]
# Solution Column Sums after deletion [19 15 13 18]
# is the solution optimal?? : False
#  6  9  1  6 | 22
#  8  1  3  7 | 4
#  3  2  4  7 | 4
#  1  1  8  7 | 17
# ---------------
#  7 11 16 13 |
#
#
# Solution Row Sums after deletion [22  4  4 17]
# Solution Column Sums after deletion [ 7 11 16 13]
# is the solution optimal?? : True
#  2  2  8  8 | 10
#  9  4  7  3 | 23
#  6  2  8  6 | 14
#  1  1  4  3 | 8
# ---------------
# 11  5 27 12 |
#
#
# Solution Row Sums after deletion [10 23 14  8]
# Solution Column Sums after deletion [11  5 27 12]
# is the solution optimal?? : True
#  8  4  7  9 | 21
#  4  5  4  4 | 13
#  3  8  1  9 | 10
#  4  3  4  8 | 11
# ---------------
# 16 12  9 18 |
#
#
# Solution Row Sums after deletion [24 13  8 12]
# Solution Column Sums after deletion [16 13 11 17]
# is the solution optimal?? : False
#  4  3  7  8 | 22
#  9  6  5  1 | 6
#  6  8  3  7 | 11
#  8  5  5  6 | 18
# ---------------
# 12 16 20  9 |
#
#
# Solution Row Sums after deletion [22  6 11 18]
# Solution Column Sums after deletion [12 16 20  9]
# is the solution optimal?? : True
#  1  9  8  1 | 18
#  4  9  7  1 | 21
#  4  1  9  5 | 5
#  6  3  4  7 | 13
# ---------------
# 10 21 19  7 |
#
#
# Solution Row Sums after deletion [18 21  5 14]
# Solution Column Sums after deletion [ 9 22 19  8]
# is the solution optimal?? : False
#  9  1  2  5 | 17
#  4  8  4  2 | 14
#  6  2  1  6 | 3
#  6  6  9  9 | 15
# ---------------
#  9 17  7 16 |
#
#
# Solution Row Sums after deletion [17 14  3 15]
# Solution Column Sums after deletion [ 9 17  7 16]
# is the solution optimal?? : True
#  6  6  4  3 | 13
#  5  5  5  1 | 11
#  8  1  4  5 | 9
#  5  9  2  6 | 13
# ---------------
# 18  7 11 10 |
#
#
# Solution Row Sums after deletion [13 11  9 13]
# Solution Column Sums after deletion [18  7 11 10]
# is the solution optimal?? : True
#  4  5  6  2 | 17
#  1  7  5  2 | 15
#  3  5  9  1 | 8
#  6  9  5  5 | 5
# ---------------
#  8 17 11  9 |
#
#
# Solution Row Sums after deletion [17 15  8  5]
# Solution Column Sums after deletion [ 8 17 11  9]
# is the solution optimal?? : True
#  3  1  9  7 | 17
#  3  3  7  5 | 18
#  4  5  9  4 | 8
#  5  5  8  3 | 8
# ---------------
# 12  4 16 19 |
#
#
# Solution Row Sums after deletion [17 18  8  8]
# Solution Column Sums after deletion [12  4 16 19]
# is the solution optimal?? : True
#  9  6  5  2 | 13
#  7  1  3  9 | 8
#  7  4  8  1 | 12
#  9  8  9  8 | 26
# ---------------
# 23 11 14 11 |
#
#
# Solution Row Sums after deletion [14  7 12 25]
# Solution Column Sums after deletion [25 12 13  8]
# is the solution optimal?? : False
#  1  5  6  1 | 6
#  6  3  8  2 | 13
#  8  9  8  7 | 23
#  4  6  4  8 | 18
# ---------------
# 13 14 16 17 |
#
#
# Solution Row Sums after deletion [ 7 13 24 16]
# Solution Column Sums after deletion [13 12 18 17]
# is the solution optimal?? : False
#  6  6  1  5 | 7
#  6  8  9  4 | 18
#  4  2  6  2 | 10
#  7  1  9  1 | 11
# ---------------
#  6 17 16  7 |
#
#
# Solution Row Sums after deletion [ 7 18 10 11]
# Solution Column Sums after deletion [ 6 17 16  7]
# is the solution optimal?? : True
#  5  3  8  2 | 18
#  4  8  3  2 | 14
#  3  8  9  6 | 12
#  7  1  5  7 | 14
# ---------------
# 19 11 17 11 |
#
#
# Solution Row Sums after deletion [18 14 12 14]
# Solution Column Sums after deletion [19 11 17 11]
# is the solution optimal?? : True
#  4  1  3  2 | 9
#  9  4  9  5 | 13
#  9  5  1  8 | 15
#  6  6  9  1 | 21
# ---------------
# 19 15 22  2 |
#
#
# Solution Row Sums after deletion [ 9 13 15 21]
# Solution Column Sums after deletion [19 15 22  2]
# is the solution optimal?? : True
#  3  6  9  7 | 10
#  1  6  7  3 | 10
#  6  1  7  8 | 21
#  3  3  2  5 | 13
# ---------------
# 12  3 16 23 |
#
#
# Solution Row Sums after deletion [10 10 21 13]
# Solution Column Sums after deletion [12  3 16 23]
# is the solution optimal?? : True
#  8  8  7  6 | 16
#  6  6  7  8 | 21
#  8  4  2  8 | 22
#  8  9  6  4 | 12
# ---------------
# 30 12  9 20 |
#
#
# Solution Row Sums after deletion [16 21 22 12]
# Solution Column Sums after deletion [30 12  9 20]
# is the solution optimal?? : True
#  3  5  1  9 | 17
#  2  2  3  4 | 5
#  9  8  2  3 | 14
#  9  1  3  4 | 14
# ---------------
# 21  8  5 16 |
#
#
# Solution Row Sums after deletion [17  5 14 14]
# Solution Column Sums after deletion [21  8  5 16]
# is the solution optimal?? : True
#  6  7  5  2 | 7
#  5  9  4  6 | 24
#  1  7  3  8 | 16
#  7  7  7  6 | 14
# ---------------
#  6 23 16 16 |
#
#
# Solution Row Sums after deletion [ 7 24 16 14]
# Solution Column Sums after deletion [ 6 23 16 16]
# is the solution optimal?? : True
#  4  9  5  3 | 16
#  1  5  5  7 | 18
#  5  3  3  7 | 15
#  3  5  9  1 | 5
# ---------------
# 10 19  8 17 |
#
#
# Solution Row Sums after deletion [16 18 15  5]
# Solution Column Sums after deletion [10 19  8 17]
# is the solution optimal?? : True
#  1  9  8  5 | 22
#  1  5  6  9 | 20
#  7  8  2  2 | 15
#  8  3  6  9 | 17
# ---------------
# 15 25 20 14 |
#
#
# Solution Row Sums after deletion [22 20 15 17]
# Solution Column Sums after deletion [15 25 20 14]
# is the solution optimal?? : True
#  1  9  1  6 | 11
#  6  6  1  6 | 13
#  9  1  4  1 | 14
#  3  8  1  7 | 8
# ---------------
# 10 15  7 14 |
#
#
# Solution Row Sums after deletion [11 13 14  8]
# Solution Column Sums after deletion [10 15  7 14]
# is the solution optimal?? : True
#  7  2  9  5 | 14
#  4  5  5  5 | 14
#  5  3  4  9 | 12
#  1  2  6  1 | 7
# ---------------
# 17 10 10 10 |
#
#
# Solution Row Sums after deletion [14 14 12  7]
# Solution Column Sums after deletion [17 10 10 10]
# is the solution optimal?? : True
#  3  8  9  3 | 14
#  5  9  5  8 | 18
#  7  9  7  9 | 25
#  6  9  3  2 | 8
# ---------------
# 14 17 12 22 |
#
#
# Solution Row Sums after deletion [12 17 25  9]
# Solution Column Sums after deletion [13 18 12 20]
# is the solution optimal?? : False
#  7  9  9  9 | 25
#  4  6  1  6 | 5
#  4  5  3  7 | 19
#  6  4  7  2 | 13
# ---------------
# 21  5 20 16 |
#
#
# Solution Row Sums after deletion [25  5 19 13]
# Solution Column Sums after deletion [21  5 20 16]
# is the solution optimal?? : True
#  4  9  1  2 | 16
#  5  8  3  1 | 4
#  4  8  5  1 | 12
#  2  9  2  4 | 15
# ---------------
# 10 26  4  7 |
#
#
# Solution Row Sums after deletion [16  5  9 15]
# Solution Column Sums after deletion [ 9 26  3  7]
# is the solution optimal?? : False
#  7  8  1  4 | 19
#  9  6  5  3 | 14
#  5  9  1  4 | 14
#  9  7  8  7 | 15
# ---------------
#  7 23 14 18 |
#
#
# Solution Row Sums after deletion [19 14 14 15]
# Solution Column Sums after deletion [ 7 23 14 18]
# is the solution optimal?? : True
#  4  3  5  6 | 8
#  5  8  7  2 | 14
#  3  2  6  7 | 12
#  9  8  9  1 | 19
# ---------------
# 17  5 21 10 |
#
#
# Solution Row Sums after deletion [ 8 14 12 19]
# Solution Column Sums after deletion [17  5 21 10]
# is the solution optimal?? : True
#  2  8  7  6 | 17
#  7  3  9  4 | 14
#  2  3  6  5 | 16
#  5  1  3  9 | 5
# ---------------
# 16 14 13  9 |
#
#
# Solution Row Sums after deletion [17 14 16  5]
# Solution Column Sums after deletion [16 14 13  9]
# is the solution optimal?? : True
#  8  4  4  6 | 22
#  9  1  2  5 | 6
#  7  3  9  6 | 18
#  2  7  2  6 | 8
# ---------------
#  8  8 15 23 |
#
#
# Solution Row Sums after deletion [22  6 18  8]
# Solution Column Sums after deletion [ 8  8 15 23]
# is the solution optimal?? : True
#  6  6  7  5 | 18
#  8  6  3  7 | 14
#  7  3  4  8 | 22
#  6  5  5  1 | 6
# ---------------
# 15 15 16 14 |
#
#
# Solution Row Sums after deletion [18 14 22  6]
# Solution Column Sums after deletion [15 15 16 14]
# is the solution optimal?? : True
#  3  1  2  7 | 5
#  7  1  9  7 | 23
#  4  5  5  4 | 13
#  2  6  7  2 | 15
# ---------------
# 16 11 18 11 |
#
#
# Solution Row Sums after deletion [ 5 23 13 15]
# Solution Column Sums after deletion [16 11 18 11]
# is the solution optimal?? : True
#  9  5  9  2 | 16
#  4  2  9  9 | 20
#  7  9  5  1 | 8
#  9  2  5  9 | 16
# ---------------
#  7  9 23 21 |
#
#
# Solution Row Sums after deletion [16 20  8 16]
# Solution Column Sums after deletion [ 7  9 23 21]
# is the solution optimal?? : True
#  7  8  7  4 | 15
#  2  6  4  6 | 6
#  6  9  4  8 | 27
#  5  9  4  6 | 24
# ---------------
# 18 32  8 14 |
#
#
# Solution Row Sums after deletion [15  6 27 24]
# Solution Column Sums after deletion [18 32  8 14]
# is the solution optimal?? : True
#  7  1  3  3 | 13
#  8  1  6  3 | 9
#  6  2  3  2 | 10
#  8  9  9  4 | 26
# ---------------
# 21 11 18  8 |
#
#
# Solution Row Sums after deletion [13  9 10 26]
# Solution Column Sums after deletion [21 11 18  8]
# is the solution optimal?? : True
#  1  4  9  7 | 17
#  3  3  6  5 | 17
#  4  4  7  4 | 8
#  1  8  5  4 | 6
# ---------------
#  9  3 20 16 |
#
#
# Solution Row Sums after deletion [17 17  8  6]
# Solution Column Sums after deletion [ 9  3 20 16]
# is the solution optimal?? : True
#  8  9  8  9 | 26
#  3  7  6  9 | 13
#  3  5  6  4 | 12
#  2  2  1  6 | 10
# ---------------
#  5 23 14 19 |
#
#
# Solution Row Sums after deletion [26 13 12 10]
# Solution Column Sums after deletion [ 5 23 14 19]
# is the solution optimal?? : True
#  9  1  8  1 | 18
#  4  9  3  5 | 12
#  6  5  9  1 | 16
#  1  7  3  4 | 10
# ---------------
# 19  8 23  6 |
#
#
# Solution Row Sums after deletion [18 12 16  8]
# Solution Column Sums after deletion [16  9 23  6]
# is the solution optimal?? : False
#  7  9  9  2 | 11
#  4  5  6  7 | 16
#  1  3  1  5 | 7
#  6  6  4  8 | 18
# ---------------
#  5 20  5 22 |
#
#
# Solution Row Sums after deletion [11 16  7 18]
# Solution Column Sums after deletion [ 5 20  5 22]
# is the solution optimal?? : True
#  6  2  8  5 | 7
#  8  4  1  2 | 11
#  7  5  2  5 | 19
#  8  8  5  5 | 13
# ---------------
# 15 15  8 12 |
#
#
# Solution Row Sums after deletion [ 7 11 19 13]
# Solution Column Sums after deletion [15 15  8 12]
# is the solution optimal?? : True
#  9  6  5  5 | 15
#  7  2  7  2 | 18
#  8  5  7  6 | 11
#  3  4  7  3 | 14
# ---------------
# 16 17 14 11 |
#
#
# Solution Row Sums after deletion [15 18 11 14]
# Solution Column Sums after deletion [16 17 14 11]
# is the solution optimal?? : True
#  8  3  9  3 | 20
#  9  5  5  6 | 16
#  4  8  8  1 | 5
#  5  6  5  5 | 16
# ---------------
# 17 11 19 10 |
#
#
# Solution Row Sums after deletion [20 16  5 16]
# Solution Column Sums after deletion [17 11 19 10]
# is the solution optimal?? : True
#  1  4  9  2 | 12
#  8  6  1  3 | 15
#  2  9  4  7 | 11
#  9  8  7  3 | 18
# ---------------
# 11 23 17  5 |
#
#
# Solution Row Sums after deletion [12 15 11 18]
# Solution Column Sums after deletion [11 23 17  5]
# is the solution optimal?? : True
#  7  3  5  3 | 15
#  2  6  5  9 | 22
#  4  1  7  6 | 11
#  4  3  4  1 | 1
# ---------------
# 13 10 10 16 |
#
#
# Solution Row Sums after deletion [15 22 11  1]
# Solution Column Sums after deletion [13 10 10 16]
# is the solution optimal?? : True
#  1  1  9  7 | 8
#  2  5  5  3 | 12
#  5  4  8  7 | 11
#  4  3  9  7 | 23
# ---------------
#  7 12 14 21 |
#
#
# Solution Row Sums after deletion [ 8 12 11 23]
# Solution Column Sums after deletion [ 7 12 14 21]
# is the solution optimal?? : True
#  8  2  5  3 | 15
#  1  9  6  1 | 17
#  5  9  8  9 | 9
#  8  2  8  4 | 20
# ---------------
# 17 11 19 14 |
#
#
# Solution Row Sums after deletion [15 17  9 20]
# Solution Column Sums after deletion [17 11 19 14]
# is the solution optimal?? : True

# %%
number_of_convergence_c
# Out:
# {5: 7, 6: 8, 7: 8, 8: 10, 9: 9}

# %%
fig3, (ax31) = plt.subplots(1,1,figsize=(12,8))

ax31.bar(number_of_convergence_m.keys(),number_of_convergence_m.values(),label = 'Solve Count',color='grey')
ax31.set_xlabel("")
# ax31.set_xticks([int(x) for x in number_of_convergence_b.keys()])
ax31.set_ylabel("Number of times solved (out of 10)")
ax31.legend()
ax31.set_title("Performance of GA algorithm with different mutation rate")

ax32 = ax31.twinx()
ax32.plot(average_generations_m.keys(),average_generations_m.values(), label='Average Generations required',color='r',marker='.')
ax32.set_ylabel("Average Generations taken by algorithm")
ax32.legend()

fig3.savefig('part_2c_a.png')

# %%
fig4, (ax41) = plt.subplots(1,1,figsize=(12,8))

ax41.bar(number_of_convergence_c.keys(),number_of_convergence_c.values(),label = 'Solve Count',color='grey')
ax41.set_xlabel("")
# ax31.set_xticks([int(x) for x in number_of_convergence_b.keys()])
ax41.set_ylabel("Number of times solved (out of 10)")
ax41.legend()
ax41.set_title("Performance of GA algorithm with different Crossover rate")

ax42 = ax41.twinx()
ax42.plot(average_generations_c.keys(),average_generations_c.values(), label='Average Generations required',color='r',marker='.')
ax42.set_ylabel("Average Generations taken by algorithm")
ax42.legend()

fig4.savefig('part_2c_b.png')
